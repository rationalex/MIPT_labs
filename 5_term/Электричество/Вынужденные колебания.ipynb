# %%
import numpy as np
import matplotlib.pyplot as plt
from math import pi, sqrt

# %%
C = 3 * 10 ** (-9)   # Ф
R = 1                # Ом
L = 100 * 10 ** (-6) # Гн
f_p = 1 / (2 * pi * sqrt(L * C))
f_p
# Out:
# 290575.8415662736

# %% [markdown]
# ## Построение резонансной кривой

# %%
#freq ampl
measures = np.array(
    [
        [2, 5.6 * 5 * 10 ** (-3)],
        [4, 6 * 10 * 10 ** (-3)],
        [5.2, 5.8 * 20 * 10 ** (-3)],
        [6.01, 3.8 * 50 * 10 ** (-3)],
        [6.23, 4.7 * 50 * 10 ** (-3)],
        [6.46, 6 * 50 * 10 ** (-3)],
        [6.68, 7.6 * 50 * 10 ** (-3)],
        [6.81, 4.4 * 10 ** (-1)],
        [6.97, 4.8 * 10 ** (-1)],
        [7.25, 4.6 * 10 ** (-1)],
        [7.51, 4.2 * 10 ** (-1)],
        [7.79, 3.6 * 10 ** (-1)],
        [8.06, 3.0 * 10 ** (-1)],
        [8.29, 2.6 * 10 ** (-1)],
        [8.4, 2.4 * 10 ** (-1)],
        [10.17, 2.6 * 50 * 10 ** (-3)],
        [12.2, 5 * 20 * 10 ** (-3)],
        [14.0, 6.4 * 10 * 10 ** (-3)],
        [16.0, 5.0 * 10 * 10 ** (-3)]
    ])

# %%
R1 = 300 # Ом
#freq ampl
measures_r1 = np.array(
    [
        [2.1, 2.8 * 10 * 10 ** (-3)],
        [4.08, 6.4 * 10 * 10 ** (-3)],
        [6.21, 4.1 * 50 * 10 ** (-3)],
        [6.3, 4.5 * 50 * 10 ** (-3)],
        [6.53, 5.4 * 50 * 10 ** (-3)],
        [6.7, 6.2 * 50 * 10 ** (-3)],
        [6.89, 6.7 * 50 * 10 ** (-3)],
        [7.1, 7.2 * 50 * 10 ** (-3)],
        [7.47, 6.8 * 50 * 10 ** (-3)],
        [7.68, 6.4 * 50 * 10 ** (-3)],
        [7.99, 5.6 * 50 * 10 ** (-3)],
        [8.27, 5.0 * 50 * 10 ** (-3)],
        [10.28, 6 * 20 * 10 ** (-3)],
        [12.1, 4 * 20 * 10 ** (-3)],
        [14.1, 3.2 * 20 * 10 ** (-3)],
        [16.7, 4.6 * 10 * 10 ** (-3)],
    ])

# %%
R2 = 3000 # Ом
#freq ampl
measures_r2 = np.array(
    [
        [2.1, 2.7 * 10 * 10 ** (-3)],
        [4.09, 3 * 20 * 10 ** (-3)],
        [6.21, 6.45 * 20 * 10 ** (-3)],
        [6.41, 2.7 * 50 * 10 ** (-3)],
        [6.63, 2.8 * 50 * 10 ** (-3)],
        [6.92, 3 * 50 * 10 ** (-3)],
        [7.1, 3.1 * 50 * 10 ** (-3)],
        [7.37, 3.0 * 50 * 10 ** (-3)],
        [7.51, 2.95 * 50 * 10 ** (-3)],
        [7.73, 2.9 * 50 * 10 ** (-3)],
        [8.05, 7.0 * 20 * 10 ** (-3)],
        [10.11, 5.2 * 20 * 10 ** (-3)],
        [12.0, 3.9 * 20 * 10 ** (-3)],
        [14.2, 2.9 * 20 * 10 ** (-3)],
        [15.9, 2.4 * 20 * 10 ** (-3)]
    ])

# %%
plt.figure(figsize=(20, 10))

plt.plot(measures[:, 0], measures[:, 1], '-o', label='1 Ом')
plt.plot(measures_r1[:, 0], measures_r1[:, 1], '-o', label='300 Ом')
plt.plot(measures_r2[:, 0], measures_r2[:, 1], '-o', label='3000 Ом')

plt.legend(loc='best')
plt.show()

# %%
R = 1 # Ом

# C freq
C = np.arange(1, 11) * 10 ** (-3)
freq = np.array([12.8,
                 8.89,
                 7.1,
                 6.12,
                 5.39,
                 4.9,
                 4.53,
                 4.23,
                 3.95,
                 3.76])

plt.figure(figsize=(16, 8))
plt.plot(C, 1 / ((2 * np.pi * freq) ** 2), '-o')
plt.show()
