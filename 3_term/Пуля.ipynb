# %%
m = [516, 523, 520, 519, 521, 517, 515, 517, 517, 525, 515, 526, 530, 516, 509, 527, 526, 523, 527, 529, 523, 518, 518, 522]
v = [165.23, 157.19, 159.27, 147.67, 164.31, 146.06, 159.64, 155.48, 141.81, 157.11, 160.09, 173.50, 178.61, 165.59, 168.08, 168.15, 186.23, 175.01, 162.63, 162.51, 152.34, 189.12, 147.19, 171.32]

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
import matplotlib.mlab as mlab
import math

# %matplotlib inline

# %%
x = np.linspace(145, 190, 200)

mu = 162
variance = 60
sigma = math.sqrt(variance)
plt.plot(x, 
         mlab.normpdf(x, mu, sigma), 
         lw=3, color='red', label='Hauss(162, 60)')

plt.hist(v, normed=True, bins=11, color = 'blue', label='Эксперимент')
plt.title("Распределение скоростей")
plt.xlabel("Скорость, м/c")
plt.ylabel("Частота")

plt.legend()

fig = plt.gcf()
