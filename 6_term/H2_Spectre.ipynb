# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#           lmbd  baraban
measures_ne = np.array(
           [[5331, 1866],
            [5341, 1872],
            [5401, 1916],
            [5852, 2182],
            [5882, 2191],
            [5945, 2228],
            [5976, 2240],
            [6030, 2269],
            [6074, 2278],
            [6096, 2292],
            [6143, 2312],
            [6164, 2324],
            [6217, 2340],
            [6267, 2359],
            [6305, 2381],
            [6334, 2389],
            [6383, 2408],
            [6402, 2412],
            [6507, 2452],
            [6533, 2462],
            [6599, 2486],
            [6678, 2516],
            [6717, 2530]])

# %%
plt.figure(figsize=(18, 8))
                                                                                                                                                                         s
plt.scatter(measures_ne[:, 0], measures_ne[:, 1], label='Углы Ne')
plt.legend(loc='best', fontsize=16)
plt.show()

# %% [markdown]
# ## H2

# %%
measures_h2 = np.array([
                 [2470],
                 [1479],
                 [834],
                 [411]
])

# %% [markdown]
# ## I

# %%
#                      
measures_i = np.array([[1968, 1939],
                       [1845, 1779],
                       [1990, 2000]])

# %% [markdown]
# ## Hg

# %%
measures_hg = np.array([[579.1, 2144],
                        [577.0, 2136],
                        [546.1, 1952],
                        [491.6, 1530],
                        [404.7, 864]])

# %%
plt.figure(figsize=(18, 8))

plt.scatter(measures_hg[:, 0], measures_hg[:, 1], label='Углы Hg')
plt.legend(loc='best', fontsize=16)
plt.show()
